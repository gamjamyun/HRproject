# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from functions import*
import serial
import time 
from config import*

# %%
lst = ListRawData(port='COM5')
# Out:
# 304
# 306
# 307
# 309
# 311
# 312
# 313
# 314
# 316
# 317
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 333
# 342
# 347
# 349
# 351
# 354
# 358
# 359
# 360
# 360
# 359
# 361
# 362
# 361
# 362
# 362
# 358
# 356
# 356
# 358
# 358
# 359
# 359
# 357
# 357
# 357
# 355
# 355
# 356
# 355
# 358
# 357
# 356
# 356
# 356
# 359
# 360
# 362
# 360
# 359
# 360
# 359
# 361
# 362
# 361
# 362
# 362
# 361
# 360
# 364
# 365
# 363
# 361
# 359
# 361
# 363
# 363
# 362
# 358
# 357
# 360
# 361
# 359
# 355
# 352
# 349
# 348
# 352
# 355
# 356
# 355
# 358
# 361
# 357
# 358
# 361
# 361
# 360
# 360
# 361
# 361
# 361
# 364
# 362
# 364
# 365
# 363
# 358
# 332
# 301
# 274
# 211
# 195
# 333
# 581
# 674
# 674
# 674
# 673
# 637
# 513
# 403
# 340
# 317
# 303
# 299
# 298
# 297
# 300
# 301
# 302
# 298
# 293
# 291
# 290
# 287
# 289
# 289
# 283
# 281
# 280
# 278
# 282
# 284
# 282
# 284
# 282
# 275
# 273
# 272
# 263
# 259
# 259
# 257
# 257
# 257
# 257
# 258
# 255
# 256
# 258
# 258
# 263
# 271
# 279
# 284
# 288
# 295
# ...

# %%
SaveList(lst[50:-50],name='xx.csv')

# %%
lst = LoadCsvToList('xx.csv',"")
for i in range(10):
    GenerateLabelList(lst,1000*i,i*1000+1000,threshold= -120)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 label_lst = []
#       2 for i in range(10):
# ----> 3     GenerateLabelList(lst,1000*i,i*1000+1000,threshold= -120)
#
# Cell In[8], line 12, in GenerateLabelList(raw_data, start_idx, end_idx, threshold, scale)
#      10 plt.plot(t_idx,raw_data[start_idx:end_idx])
#      11 for i in range(len(raw_data[start_idx:end_idx])):
# ---> 12     if raw_data[start_idx+i-1]-raw_data[start_idx+i-2]<threshold and raw_data[start_idx+i]-raw_data[start_idx+i-1]>threshold:
#      13         label_lst.append(start_idx+i)
#      14         plt.scatter(start_idx+i,raw_data[start_idx+i],color = 'r')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
